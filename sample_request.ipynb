# %%
import requests,json

# %%
url = 'http://porrello.pythonanywhere.com/getDataFile'
url = 'http://127.0.0.1:8000/getDataFile'
data = {"username": "_fronji", "password":"81216163Xx_"}
headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}

res = requests.post(url,data=json.dumps(data),headers=headers).json()
 
print(res)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connectionpool.py:699, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     <a href='file:///c%3A/Users/Mashood/AppData/Local/Programs/Python/Python38/lib/site-packages/urllib3/connectionpool.py?line=697'>698</a> # Make the request on the httplib connection object.
# --> <a href='file:///c%3A/Users/Mashood/AppData/Local/Programs/Python/Python38/lib/site-packages/urllib3/connectionpool.py?line=698'>699</a> httplib_response = self._make_request(
#     <a href='file:///c%3A/Users/Mashood/AppData/Local/Programs/Python/Python38/lib/site-packages/urllib3/connectionpool.py?line=699'>700</a>     conn,
# ...

# %%
# python3 live_broadcast.py -u _fronji -p 81216163Xx_ -proxy user:password@ip:port
